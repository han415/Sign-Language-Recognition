# %%
# !pip install selenium==4.1.1
# Out:
# ...
#   Obtaining dependency information for selenium==4.1.1 from https://files.pythonhosted.org/packages/ae/0e/0af3a868fd9e2af33821695e44a65d16ef14fc9388c1eb55434257617c02/selenium-4.1.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for trio~=0.17 from https://files.pythonhosted.org/packages/17/c9/f86f89f14d52f9f2f652ce24cb2f60141a51d087db1563f3fba94ba07346/trio-0.25.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for trio-websocket~=0.9 from https://files.pythonhosted.org/packages/48/be/a9ae5f50cad5b6f85bd2574c2c923730098530096e170c1ce7452394d7aa/trio_websocket-0.11.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for attrs>=23.2.0 from https://files.pythonhosted.org/packages/e0/44/827b2a91a5816512fcaf3cc4ebc465ccd5d598c45cefa6703fcf4a79018f/attrs-23.2.0-py3-none-any.whl.metadata
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

driver=webdriver.Chrome(r"C:\Users\User\Desktop\0514\chromedriver.exe")

default_url="https://www.google.com/search?q=translate&sca_esv=4771c1dce5b9df5f&rlz=1C1CHBF_zh-TWTW1088TW1089&sxsrf=ADLYWIJZdy6n2Q13AZ_zXS_5G0H-F2L_RA%3A1715616048732&ei=MDlCZuOTLMHg2roPrcau2Ao&ved=0ahUKEwjj657p_4qGAxVBsFYBHS2jC6sQ4dUDCBA&uact=5&oq=translate&gs_lp=Egxnd3Mtd2l6LXNlcnAiCXRyYW5zbGF0ZTIKECMYgAQYJxiKBTILEAAYgAQYsQMYgwEyCxAAGIAEGLEDGIMBMgsQABiABBixAxiDATIFEAAYgAQyBRAAGIAEMgUQABiABDIFEAAYgAQyBRAAGIAEMgUQABiABEi-SVCVCFiWQHADeAGQAQCYATegAeIEqgECMTK4AQPIAQD4AQGYAg-&sclient=gws-wiz-serp"
driver.get(default_url)
time.sleep(1)

driver.find_element(By.XPATH,'//*[@id="tw-source-text-ta"]').send_keys("hi")
time.sleep(3)

translate=driver.find_element(By.CLASS_NAME,'Y2IQFc').text
print(translate)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2980\664454307.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\User\Desktop\0514\chromedriver.exe")

# %%
pip install googletrans==3.1.0a0
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Obtaining dependency information for httpx==0.13.3 from https://files.pythonhosted.org/packages/54/b4/698b284c6aed4d7c2b4fe3ba5df1fcf6093612423797e76fbb24890dd22f/httpx-0.13.3-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for hstspreload from https://files.pythonhosted.org/packages/39/fd/faadcac67dbeeb0c85faf64ce6481e88cfa1f60643f246d1326c13934466/hstspreload-2024.5.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for chardet==3.* from https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for idna==2.* from https://files.pythonhosted.org/packages/a2/38/928ddce2273eaa564f6f50de919327bf3a00f091b5baba8dfa9460f3a8a8/idna-2.10-py2.py3-none-any.whl.metadata
# ...

# %%
import googletrans
from pprint import pprint

translator=googletrans.Translator()
result=translator.translate('Hi!Nice to meet you!',dest='zh-tw')

print(result.text)
# Out:
# 你好，很高興見到你！
